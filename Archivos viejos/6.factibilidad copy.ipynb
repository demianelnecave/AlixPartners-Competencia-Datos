# %% [markdown]
# #### **FACTIBILIDAD DE LA SOLUCIÓN**

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from importlib import reload
import copy

import Clases.asignacion as asignacion_module
reload(asignacion_module)
from Clases.asignacion import Asignacion

import Clases.caja as caja_module
reload(caja_module)
from Clases.caja import Caja

import Clases.producto as producto_module
reload(producto_module)
from Clases.producto import Producto

import Clases.solucion as solucion_module
reload(solucion_module)
from Clases.solucion import Solucion

catalogo_productos = pd.read_csv("Datos-finales/catalogo_productos.csv")
especificaciones_cajas = pd.read_csv("Datos-finales/especificaciones_cajas.csv")
operaciones_planta = pd.read_csv("Datos-finales/operaciones_planta.csv")
procurement_cajas = pd.read_csv("Datos-finales/procurement_cajas.csv")

cajas_redimensionadas_5mm = pd.read_csv("Redimensionamientos/redimensionamientos_5mm.csv")
cajas_redimensionadas_4p5mm = pd.read_csv("Redimensionamientos/redimensionamientos_4.5mm.csv")
cajas_redimensionadas_3mm = pd.read_csv("Redimensionamientos/redimensionamientos_3mm.csv")

# %% [markdown]
# Guardamos primero los tipos de cajas y los productos en listas de python.

# %%
cajas = {
    row["caja_tipo_id"]: Caja(
        caja_id=row["caja_tipo_id"],
        dim_interior_ancho=row["caja_interior_ancho"],
        dim_interior_largo=row["caja_interior_largo"],
        dim_interior_alto=row["caja_interior_alto"]
    )
    for _, row in especificaciones_cajas.iterrows()
}

# %%
prod_op_merge = catalogo_productos.merge(operaciones_planta, on="codigo_producto")

productos = {
    row["codigo_producto"]: Producto(
        codigo_producto = row['codigo_producto'],
        cantidad_paquetes = row['cantidad_paquetes'],
        peso_paquete = row['peso_neto_paquete'],
        demanda_buenos_aires = row['volumen_producto_planta_buenos_aires'],
        demanda_curitiba = row['volumen_producto_planta_curitiba'],
        demanda_santiago = row['volumen_producto_planta_santiago'],
        demanda_monterrey = row['volumen_producto_planta_monterrey'],
        demanda_bakersfield = row['volumen_producto_planta_bakersfield'],
        dim_producto_ancho = row['dim_producto_ancho'], 
        dim_producto_largo = row['dim_producto_largo'],
        dim_producto_alto = row['dim_producto_alto']
    )
    for _, row in prod_op_merge.iterrows()
}

# %% [markdown]
# #### **Factibilidad con grosor = 5mm**

# %% [markdown]
# La idea sería ver cuántos tipos de cajas se pueden asignar por producto, considerando las restricciones de dimensión interna, headspace y resistencia a comprensión. Cada chequeo se verifica dentro de la class Asignacion.

# %% [markdown]
# Empecemos viendo la factiblidad con un tamaño de grosor de 5mm, importando antes las cajas redimensionadas.

# %%
cajas_5mm = cajas.copy()

for caja_id, caja in cajas_5mm.items(): 
    caja.elegir_grosor(5)

redimensiones_por_caja_5mm = {}

# Importamos las redimensiones posibles
for caja_id, caja in cajas_5mm.items():
    redimensiones_por_caja_5mm[caja_id] = []
    # Buscamos todas las combinaciones de redimensionamiento del tipo de caja
    combinaciones_caja = cajas_redimensionadas_5mm[cajas_redimensionadas_5mm['caja_id'] == caja_id]
    
    for _, row in combinaciones_caja.iterrows():
        redimensiones_por_caja_5mm[caja_id].append({
            'alto': row['alto'],
            'ancho': row['ancho'],
            'largo': row['largo'],
            'utilizacion_pallet': row['utilizacion'],
            'cantidad_cajas_pallet': row['cantidad_cajas_pallet']
        })
        
        # Ordenamos según la utilizacion de pallet de mayor a menor
        redimensiones_por_caja_5mm[caja_id] = sorted(
            redimensiones_por_caja_5mm[caja_id],
            key=lambda x: x['utilizacion_pallet'],
            reverse=True
        )

# %% [markdown]
# Chequeamos factibilidad de asignación para todas las redimensiones determinadas de los tipos de caja.

# %%
redimensiones_cajas_factibles_5mm = {}

for codigo, producto in productos.items():
    redimensiones_asignables = {}
    
    for caja_id, caja in cajas_5mm.items():
        redimensiones_validas_caja = []
        # Iteramos sobre cada combinación posible de redimensionamiento
        for combinacion in redimensiones_por_caja_5mm[caja_id]:
            caja_redimensionada = copy.deepcopy(caja)
            caja_redimensionada.redimensionar(combinacion['alto'], combinacion['ancho'], combinacion['largo'])
            
            # Chequeo factibilidad de la asignacion
            asignacion = Asignacion(producto, caja_redimensionada)
            if asignacion.es_asignacion_valida() and caja_redimensionada.utilizacion_pallet() >= 0.7: 
                redimensiones_validas_caja.append(combinacion)
        
        if len(redimensiones_validas_caja) != 0:
            redimensiones_asignables[caja_id] = redimensiones_validas_caja
    
    redimensiones_cajas_factibles_5mm[codigo] = redimensiones_asignables

# %% [markdown]
# Veamos en detalle cuántos tipos de cajas son asignables por cada producto.

# %%
df_factibilidad_5mm = pd.DataFrame([
    {
        'codigo_producto': codigo_producto,
        'cantidad_cajas_asignables': len(cajas_asign),
    }
    for codigo_producto, cajas_asign in redimensiones_cajas_factibles_5mm.items()
])

df_factibilidad_5mm = df_factibilidad_5mm.sort_values('cantidad_cajas_asignables', ascending=False)
df_factibilidad_5mm
# Out:
#     codigo_producto  cantidad_cajas_asignables
# 302          BR0300                         97
# 304          BR0302                         96
# 97           BR0097                         95
# 247          BR0245                         94
# 248          BR0246                         93
# ..              ...                        ...
# 214          BR0212                          6
# 124          BR0124                          2
# 122          BR0122                          2
# 44           BR0045                          1
# 57           BR0058                          1
#
# [427 rows x 2 columns]

# %% [markdown]
# Observemos que el espacio de búsqueda se redujo hasta la mitad mínimamente, y como máximo se pueden asignar 107 tipos de cajas a un mismo producto, siendo el caso de BR0241.
#
# Veamos cómo se distribuye esta cantidad en un gráfico.

# %%
plt.figure(figsize=(10, 5))
plt.hist(df_factibilidad_5mm['cantidad_cajas_asignables'].dropna(), bins=15,
         color='brown', rwidth=0.9)
plt.title('Distribución de cantidad de cajas asignables por producto')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Podemos notar que la mayoría de productos suelen poder utilizar hasta 60 tipos de cajas, y sólo pocos casos utilizan más de 100. Comparando con la situación original de 204 tipos de cajas, esta reducción nos genera una gran ventaja en la optimización posterior.

# %% [markdown]
# Por otro lado, podría llegar a ser interesante ver cuántos productos son asignables por tipo de caja, y en particular ver cuál es la redimensionalidad más elegible.
#
# Además de aumentar los descuentos por los volúmenes altos, esto reduciría significativamente la cantidad de tipos de cajas utilizados.

# %%
conteo_redimensiones = {}

for codigo_producto, cajas_asignables in redimensiones_cajas_factibles_5mm.items():
    for caja_id, redimensiones in cajas_asignables.items():
        # Si la caja no existe, crearla
        if caja_id not in conteo_redimensiones:
            conteo_redimensiones[caja_id] = {}
        
        for combinacion in redimensiones:
            clave_redim = (
                combinacion['alto'],
                combinacion['ancho'],
                combinacion['largo'],
                combinacion['utilizacion_pallet'],
                combinacion['cantidad_cajas_pallet']
            )
            
            # Si la clave no existe, inicializarla en 0
            if clave_redim not in conteo_redimensiones[caja_id]:
                conteo_redimensiones[caja_id][clave_redim] = 0
            
            # Incrementar
            conteo_redimensiones[caja_id][clave_redim] += 1

# %%
data = []

for caja_id, redimensiones in conteo_redimensiones.items():
    for (alto, ancho, largo, utilizacion, cajas_pallet), cantidad in redimensiones.items():
        data.append({
            'caja_id': caja_id,
            'alto': alto,
            'ancho': ancho,
            'largo': largo,
            'utilizacion_pallet': utilizacion,
            'cantidad_cajas_pallet': cajas_pallet,
            'cantidad_productos': cantidad
        })

df_conteo = pd.DataFrame(data)

# Ordenar por cantidad de productos (de mayor a menor)
df_conteo = df_conteo.sort_values(['caja_id', 'utilizacion_pallet'], ascending=[True, False])
df_conteo
# Out:
#                                caja_id   alto  ancho  largo  \
# 1458  02cf77de65b70dd77905e2e33d78478f  320.1  266.4  355.5
# 1456  02cf77de65b70dd77905e2e33d78478f  261.9  266.4  355.5
# 1457  02cf77de65b70dd77905e2e33d78478f  291.0  266.4  355.5
# 1324  082c1cdb42b1abd201403ca33ca11ef0  189.0  272.8  383.0
# 1321  082c1cdb42b1abd201403ca33ca11ef0  207.9  272.8  383.0
# ...                                ...    ...    ...    ...
# 858   fe7802fb3f92b710413a4de88233a3f7  191.4  316.8  388.0
# 853   fe7802fb3f92b710413a4de88233a3f7  191.4  259.2  349.2
# 1401  fea00d6f87d3f80808e9e8d1b501120a  165.6  266.4  355.5
# 1400  fea00d6f87d3f80808e9e8d1b501120a  184.0  266.4  355.5
# 1399  fea00d6f87d3f80808e9e8d1b501120a  202.4  266.4  355.5
#
#       utilizacion_pallet  cantidad_cajas_pallet  cantidad_productos
# 1458            0.771946                   40.0                   1
# 1456            0.763013                   48.0                  20
# ...

# %% [markdown]
# Notemos que la mayoría de tipos de cajas pueden ser asignados a varios productos, siendo el valor máximo un total de 62 productos. La selección óptima explica que comprar más de esos tipos de cajas permitiría que haya un mayor descuento por compra.

# %% [markdown]
# Exportemos los resultados a csv:

# %%
data = []

for codigo_producto, cajas_asignables in redimensiones_cajas_factibles_5mm.items():
    for caja_id, redimensiones in cajas_asignables.items():
        for combinacion in redimensiones:
            data.append({
                'codigo_producto': codigo_producto,
                'demanda_total': productos[codigo_producto].demanda_total(),
                'caja_tipo_id': caja_id,
                'alto': combinacion['alto'],
                'ancho': combinacion['ancho'],
                'largo': combinacion['largo'],
                'utilizacion_pallet': combinacion['utilizacion_pallet'],
                'cantidad_cajas_pallet': combinacion['cantidad_cajas_pallet']
            })

df_exportar = pd.DataFrame(data)
df_exportar.to_csv('Factibilidad/factibilidad2_5mm.csv', index=False)

# %% [markdown]
# #### **Factibilidad con grosor = 3mm**

# %% [markdown]
# La idea sería ver cuántos tipos de cajas se pueden asignar por producto, considerando las restricciones de dimensión interna, headspace y resistencia a comprensión. Cada chequeo se verifica dentro de la class Asignacion.

# %% [markdown]
# Empecemos viendo la factiblidad con un tamaño de grosor de 5mm, importando antes las cajas redimensionadas.

# %%
cajas_3mm = cajas.copy()

for caja_id, caja in cajas_3mm.items(): 
    caja.elegir_grosor(3)

redimensiones_por_caja_3mm = {}

# Importamos las redimensiones posibles
for caja_id, caja in cajas_3mm.items():
    redimensiones_por_caja_3mm[caja_id] = []
    # Buscamos todas las combinaciones de redimensionamiento del tipo de caja
    combinaciones_caja = cajas_redimensionadas_3mm[cajas_redimensionadas_3mm['caja_id'] == caja_id]
    
    for _, row in combinaciones_caja.iterrows():
        redimensiones_por_caja_3mm[caja_id].append({
            'alto': row['alto'],
            'ancho': row['ancho'],
            'largo': row['largo'],
            'utilizacion_pallet': row['utilizacion'],
            'cantidad_cajas_pallet': row['cantidad_cajas_pallet']
        })
        
        # Ordenamos según la utilizacion de pallet de mayor a menor
        redimensiones_por_caja_3mm[caja_id] = sorted(
            redimensiones_por_caja_3mm[caja_id],
            key=lambda x: x['utilizacion_pallet'],
            reverse=True
        )

# %% [markdown]
# Chequeamos factibilidad de asignación para todas las redimensiones determinadas de los tipos de caja.

# %%
redimensiones_cajas_factibles_3mm = {}

for codigo, producto in productos.items():
    redimensiones_asignables = {}
    
    for caja_id, caja in cajas_3mm.items():
        redimensiones_validas_caja = []
        # Iteramos sobre cada combinación posible de redimensionamiento
        for combinacion in redimensiones_por_caja_3mm[caja_id]:
            caja_redimensionada = copy.deepcopy(caja)
            caja_redimensionada.redimensionar(combinacion['alto'], combinacion['ancho'], combinacion['largo'])
            
            # Chequeo factibilidad de la asignacion
            asignacion = Asignacion(producto, caja_redimensionada)
            if asignacion.es_asignacion_valida() and caja_redimensionada.utilizacion_pallet() >= 0.7: 
                redimensiones_validas_caja.append(combinacion)
        
        if len(redimensiones_validas_caja) != 0:
            redimensiones_asignables[caja_id] = redimensiones_validas_caja
    
    redimensiones_cajas_factibles_3mm[codigo] = redimensiones_asignables

# %% [markdown]
# Veamos en detalle cuántos tipos de cajas son asignables por cada producto.

# %%
df_factibilidad_3mm = pd.DataFrame([
    {
        'codigo_producto': codigo_producto,
        'cantidad_cajas_asignables': len(cajas_asign),
    }
    for codigo_producto, cajas_asign in redimensiones_cajas_factibles_3mm.items()
])

df_factibilidad_3mm = df_factibilidad_3mm.sort_values('cantidad_cajas_asignables', ascending=False)
df_factibilidad_3mm
# Out:
#     codigo_producto  cantidad_cajas_asignables
# 248          BR0246                         78
# 247          BR0245                         76
# 97           BR0097                         75
# 304          BR0302                         74
# 53           BR0054                         73
# ..              ...                        ...
# 214          BR0212                          2
# 122          BR0122                          1
# 124          BR0124                          1
# 57           BR0058                          1
# 44           BR0045                          1
#
# [427 rows x 2 columns]

# %% [markdown]
# Observemos que el espacio de búsqueda se redujo hasta la mitad mínimamente, y como máximo se pueden asignar 107 tipos de cajas a un mismo producto, siendo el caso de BR0241.
#
# Veamos cómo se distribuye esta cantidad en un gráfico.

# %%
plt.figure(figsize=(10, 5))
plt.hist(df_factibilidad_5mm['cantidad_cajas_asignables'].dropna(), bins=15,
         color='brown', rwidth=0.9)
plt.title('Distribución de cantidad de cajas asignables por producto')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Podemos notar que la mayoría de productos suelen poder utilizar hasta 60 tipos de cajas, y sólo pocos casos utilizan más de 100. Comparando con la situación original de 204 tipos de cajas, esta reducción nos genera una gran ventaja en la optimización posterior.

# %% [markdown]
# Por otro lado, podría llegar a ser interesante ver cuántos productos son asignables por tipo de caja, y en particular ver cuál es la redimensionalidad más elegible.
#
# Además de aumentar los descuentos por los volúmenes altos, esto reduciría significativamente la cantidad de tipos de cajas utilizados.

# %%
conteo_redimensiones = {}

for codigo_producto, cajas_asignables in redimensiones_cajas_factibles_3mm.items():
    for caja_id, redimensiones in cajas_asignables.items():
        # Si la caja no existe, crearla
        if caja_id not in conteo_redimensiones:
            conteo_redimensiones[caja_id] = {}
        
        for combinacion in redimensiones:
            clave_redim = (
                combinacion['alto'],
                combinacion['ancho'],
                combinacion['largo'],
                combinacion['utilizacion_pallet'],
                combinacion['cantidad_cajas_pallet']
            )
            
            # Si la clave no existe, inicializarla en 0
            if clave_redim not in conteo_redimensiones[caja_id]:
                conteo_redimensiones[caja_id][clave_redim] = 0
            
            # Incrementar
            conteo_redimensiones[caja_id][clave_redim] += 1

# %%
data = []

for caja_id, redimensiones in conteo_redimensiones.items():
    for (alto, ancho, largo, utilizacion, cajas_pallet), cantidad in redimensiones.items():
        data.append({
            'caja_id': caja_id,
            'alto': alto,
            'ancho': ancho,
            'largo': largo,
            'utilizacion_pallet': utilizacion,
            'cantidad_cajas_pallet': cajas_pallet,
            'cantidad_productos': cantidad
        })

df_conteo = pd.DataFrame(data)

# Ordenar por cantidad de productos (de mayor a menor)
df_conteo = df_conteo.sort_values(['caja_id', 'utilizacion_pallet'], ascending=[True, False])
df_conteo
# Out:
#                                caja_id   alto  ancho  largo  \
# 1268  02cf77de65b70dd77905e2e33d78478f  291.0  266.4  355.5
# 1039  082c1cdb42b1abd201403ca33ca11ef0  170.1  272.8  383.0
# 1037  082c1cdb42b1abd201403ca33ca11ef0  189.0  272.8  383.0
# 1038  082c1cdb42b1abd201403ca33ca11ef0  207.9  272.8  383.0
# 1036  082c1cdb42b1abd201403ca33ca11ef0  189.0  248.0  383.0
# ...                                ...    ...    ...    ...
# 368   fe7802fb3f92b710413a4de88233a3f7  174.0  259.2  388.0
# 371   fe7802fb3f92b710413a4de88233a3f7  156.6  259.2  388.0
# 367   fe7802fb3f92b710413a4de88233a3f7  191.4  259.2  388.0
# 369   fe7802fb3f92b710413a4de88233a3f7  191.4  259.2  349.2
# 1284  fea00d6f87d3f80808e9e8d1b501120a  184.0  266.4  355.5
#
#       utilizacion_pallet  cantidad_cajas_pallet  cantidad_productos
# 1268            0.812399                   48.0                   1
# 1039            0.884195                   80.0                   2
# ...

# %% [markdown]
# Notemos que la mayoría de tipos de cajas pueden ser asignados a varios productos, siendo el valor máximo un total de 62 productos. La selección óptima explica que comprar más de esos tipos de cajas permitiría que haya un mayor descuento por compra.

# %% [markdown]
# Exportemos los resultados a csv:

# %%
data = []

for codigo_producto, cajas_asignables in redimensiones_cajas_factibles_5mm.items():
    for caja_id, redimensiones in cajas_asignables.items():
        for combinacion in redimensiones:
            data.append({
                'codigo_producto': codigo_producto,
                'demanda_total': productos[codigo_producto].demanda_total(),
                'caja_tipo_id': caja_id,
                'alto': combinacion['alto'],
                'ancho': combinacion['ancho'],
                'largo': combinacion['largo'],
                'utilizacion_pallet': combinacion['utilizacion_pallet'],
                'cantidad_cajas_pallet': combinacion['cantidad_cajas_pallet']
            })

df_exportar = pd.DataFrame(data)
df_exportar.to_csv('Factibilidad/factibilidad2_3mm.csv', index=False)

# %% [markdown]
# #### **Factibilidad con grosor = 4.5mm**

# %% [markdown]
# La idea sería ver cuántos tipos de cajas se pueden asignar por producto, considerando las restricciones de dimensión interna, headspace y resistencia a comprensión. Cada chequeo se verifica dentro de la class Asignacion.

# %% [markdown]
# Empecemos viendo la factiblidad con un tamaño de grosor de 5mm, importando antes las cajas redimensionadas.

# %%
cajas_4p5mm = cajas.copy()

for caja_id, caja in cajas_4p5mm.items(): 
    caja.elegir_grosor(4.5)

redimensiones_por_caja_4p5mm = {}

# Importamos las redimensiones posibles
for caja_id, caja in cajas_4p5mm.items():
    redimensiones_por_caja_4p5mm[caja_id] = []
    # Buscamos todas las combinaciones de redimensionamiento del tipo de caja
    combinaciones_caja = cajas_redimensionadas_4p5mm[cajas_redimensionadas_4p5mm['caja_id'] == caja_id]
    
    for _, row in combinaciones_caja.iterrows():
        redimensiones_por_caja_4p5mm[caja_id].append({
            'alto': row['alto'],
            'ancho': row['ancho'],
            'largo': row['largo'],
            'utilizacion_pallet': row['utilizacion'],
            'cantidad_cajas_pallet': row['cantidad_cajas_pallet']
        })
        
        # Ordenamos según la utilizacion de pallet de mayor a menor
        redimensiones_por_caja_4p5mm[caja_id] = sorted(
            redimensiones_por_caja_4p5mm[caja_id],
            key=lambda x: x['utilizacion_pallet'],
            reverse=True
        )

# %% [markdown]
# Chequeamos factibilidad de asignación para todas las redimensiones determinadas de los tipos de caja.

# %%
redimensiones_cajas_factibles_4p5mm = {}

for codigo, producto in productos.items():
    redimensiones_asignables = {}
    
    for caja_id, caja in cajas_4p5mm.items():
        redimensiones_validas_caja = []
        # Iteramos sobre cada combinación posible de redimensionamiento
        for combinacion in redimensiones_por_caja_4p5mm[caja_id]:
            caja_redimensionada = copy.deepcopy(caja)
            caja_redimensionada.redimensionar(combinacion['alto'], combinacion['ancho'], combinacion['largo'])
            
            # Chequeo factibilidad de la asignacion
            asignacion = Asignacion(producto, caja_redimensionada)
            if asignacion.es_asignacion_valida() and caja_redimensionada.utilizacion_pallet() >= 0.7: 
                redimensiones_validas_caja.append(combinacion)
        
        if len(redimensiones_validas_caja) != 0:
            redimensiones_asignables[caja_id] = redimensiones_validas_caja
    
    redimensiones_cajas_factibles_4p5mm[codigo] = redimensiones_asignables

# %% [markdown]
# Veamos en detalle cuántos tipos de cajas son asignables por cada producto.

# %%
df_factibilidad_4p5mm = pd.DataFrame([
    {
        'codigo_producto': codigo_producto,
        'cantidad_cajas_asignables': len(cajas_asign),
    }
    for codigo_producto, cajas_asign in redimensiones_cajas_factibles_4p5mm.items()
])

df_factibilidad_4p5mm = df_factibilidad_4p5mm.sort_values('cantidad_cajas_asignables', ascending=False)
df_factibilidad_4p5mm
# Out:
#     codigo_producto  cantidad_cajas_asignables
# 304          BR0302                         93
# 302          BR0300                         93
# 97           BR0097                         91
# 52           BR0053                         87
# 49           BR0050                         87
# ..              ...                        ...
# 214          BR0212                          4
# 122          BR0122                          3
# 124          BR0124                          3
# 44           BR0045                          1
# 57           BR0058                          1
#
# [427 rows x 2 columns]

# %% [markdown]
# Observemos que el espacio de búsqueda se redujo hasta la mitad mínimamente, y como máximo se pueden asignar 107 tipos de cajas a un mismo producto, siendo el caso de BR0241.
#
# Veamos cómo se distribuye esta cantidad en un gráfico.

# %%
plt.figure(figsize=(10, 5))
plt.hist(df_factibilidad_4p5mm['cantidad_cajas_asignables'].dropna(), bins=15,
         color='brown', rwidth=0.9)
plt.title('Distribución de cantidad de cajas asignables por producto')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Podemos notar que la mayoría de productos suelen poder utilizar hasta 60 tipos de cajas, y sólo pocos casos utilizan más de 100. Comparando con la situación original de 204 tipos de cajas, esta reducción nos genera una gran ventaja en la optimización posterior.

# %% [markdown]
# Por otro lado, podría llegar a ser interesante ver cuántos productos son asignables por tipo de caja, y en particular ver cuál es la redimensionalidad más elegible.
#
# Además de aumentar los descuentos por los volúmenes altos, esto reduciría significativamente la cantidad de tipos de cajas utilizados.

# %%
conteo_redimensiones = {}

for codigo_producto, cajas_asignables in redimensiones_cajas_factibles_4p5mm.items():
    for caja_id, redimensiones in cajas_asignables.items():
        # Si la caja no existe, crearla
        if caja_id not in conteo_redimensiones:
            conteo_redimensiones[caja_id] = {}
        
        for combinacion in redimensiones:
            clave_redim = (
                combinacion['alto'],
                combinacion['ancho'],
                combinacion['largo'],
                combinacion['utilizacion_pallet'],
                combinacion['cantidad_cajas_pallet']
            )
            
            # Si la clave no existe, inicializarla en 0
            if clave_redim not in conteo_redimensiones[caja_id]:
                conteo_redimensiones[caja_id][clave_redim] = 0
            
            # Incrementar
            conteo_redimensiones[caja_id][clave_redim] += 1

# %%
data = []

for caja_id, redimensiones in conteo_redimensiones.items():
    for (alto, ancho, largo, utilizacion, cajas_pallet), cantidad in redimensiones.items():
        data.append({
            'caja_id': caja_id,
            'alto': alto,
            'ancho': ancho,
            'largo': largo,
            'utilizacion_pallet': utilizacion,
            'cantidad_cajas_pallet': cajas_pallet,
            'cantidad_productos': cantidad
        })

df_conteo = pd.DataFrame(data)

# Ordenar por cantidad de productos (de mayor a menor)
df_conteo = df_conteo.sort_values(['caja_id', 'utilizacion_pallet'], ascending=[True, False])
df_conteo
# Out:
#                                caja_id   alto  ancho  largo  \
# 1319  02cf77de65b70dd77905e2e33d78478f  291.0  266.4  355.5
# 1320  02cf77de65b70dd77905e2e33d78478f  320.1  266.4  355.5
# 1318  02cf77de65b70dd77905e2e33d78478f  261.9  266.4  355.5
# 1172  082c1cdb42b1abd201403ca33ca11ef0  170.1  272.8  383.0
# 1173  082c1cdb42b1abd201403ca33ca11ef0  189.0  272.8  383.0
# ...                                ...    ...    ...    ...
# 621   fe7802fb3f92b710413a4de88233a3f7  191.4  316.8  388.0
# 619   fe7802fb3f92b710413a4de88233a3f7  191.4  259.2  349.2
# 1267  fea00d6f87d3f80808e9e8d1b501120a  165.6  266.4  355.5
# 1266  fea00d6f87d3f80808e9e8d1b501120a  184.0  266.4  355.5
# 1265  fea00d6f87d3f80808e9e8d1b501120a  202.4  266.4  355.5
#
#       utilizacion_pallet  cantidad_cajas_pallet  cantidad_productos
# 1319            0.836527                   48.0                   5
# 1320            0.764726                   40.0                   1
# ...

# %% [markdown]
# Notemos que la mayoría de tipos de cajas pueden ser asignados a varios productos, siendo el valor máximo un total de 62 productos. La selección óptima explica que comprar más de esos tipos de cajas permitiría que haya un mayor descuento por compra.

# %% [markdown]
# Exportemos los resultados a csv:

# %%
data = []

for codigo_producto, cajas_asignables in redimensiones_cajas_factibles_4p5mm.items():
    for caja_id, redimensiones in cajas_asignables.items():
        for combinacion in redimensiones:
            data.append({
                'codigo_producto': codigo_producto,
                'demanda_total': productos[codigo_producto].demanda_total(),
                'caja_tipo_id': caja_id,
                'alto': combinacion['alto'],
                'ancho': combinacion['ancho'],
                'largo': combinacion['largo'],
                'utilizacion_pallet': combinacion['utilizacion_pallet'],
                'cantidad_cajas_pallet': combinacion['cantidad_cajas_pallet']
            })

df_exportar = pd.DataFrame(data)
df_exportar.to_csv('Factibilidad/factibilidad2_4p5mm.csv', index=False)
