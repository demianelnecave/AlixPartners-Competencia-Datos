# %% [markdown]
# #### **OPTIMALIDAD DE LA SOLUCION - ALGORITMOS GREEDY**

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from importlib import reload
import random

import Clases.asignacion as asignacion_module
reload(asignacion_module)
from Clases.asignacion import Asignacion

import Clases.caja as caja_module
reload(caja_module)
from Clases.caja import Caja

import Clases.producto as producto_module
reload(producto_module)
from Clases.producto import Producto

import Clases.solucion as solucion_module
reload(solucion_module)
from Clases.solucion import Solucion

catalogo_productos = pd.read_csv("Datos-finales/catalogo_productos.csv")
especificaciones_cajas = pd.read_csv("Datos-finales/especificaciones_cajas.csv")
operaciones_planta = pd.read_csv("Datos-finales/operaciones_planta.csv")
procurement_cajas = pd.read_csv("Datos-finales/procurement_cajas.csv")

factibilidad_5mm = pd.read_csv("Factibilidad/factibilidad2_5mm.csv")

cajas_redimensionadas_5mm = pd.read_csv("Redimensionamientos/redimensionamientos_5mm.csv")
cajas_redimensionadas_4pmm = pd.read_csv("Redimensionamientos/redimensionamientos_4.5mm.csv")
cajas_redimensionadas_3mm = pd.read_csv("Redimensionamientos/redimensionamientos_3mm.csv")

# %% [markdown]
# Empecemos guardando los productos y tipos de cajas en listas en el estado actual, para cargarlos luego a las soluciones. Calculamos también las cajas asignables a cada producto en la lista de productos.

# %%
def guardar_cajas_y_productos(grosor):
    cajas = {
        row["caja_tipo_id"]: Caja(
            caja_id=row["caja_tipo_id"],
            dim_interior_ancho=row["caja_interior_ancho"],
            dim_interior_largo=row["caja_interior_largo"],
            dim_interior_alto=row["caja_interior_alto"]
        )
        for _, row in especificaciones_cajas.iterrows()
    }

    prod_op_merge = catalogo_productos.merge(operaciones_planta, on="codigo_producto")
    productos = {
        row["codigo_producto"]: Producto(
            codigo_producto = row['codigo_producto'],
            cantidad_paquetes = row['cantidad_paquetes'],
            peso_paquete = row['peso_neto_paquete'],
            demanda_buenos_aires = row['volumen_producto_planta_buenos_aires'],
            demanda_curitiba = row['volumen_producto_planta_curitiba'],
            demanda_santiago = row['volumen_producto_planta_santiago'],
            demanda_monterrey = row['volumen_producto_planta_monterrey'],
            demanda_bakersfield = row['volumen_producto_planta_bakersfield'],
            dim_producto_ancho = row['dim_producto_ancho'], 
            dim_producto_largo = row['dim_producto_largo'],
            dim_producto_alto = row['dim_producto_alto']
        )
        for _, row in prod_op_merge.iterrows()
    }
    
    # Crear todas las asignaciones por producto con las redimensiones válidas            
    asignaciones_por_producto = {}

    for codigo_producto, grupo_producto in factibilidad_5mm.groupby('codigo_producto'):
        producto = productos[codigo_producto]
        
        asignaciones_por_producto[codigo_producto] = {}
        
        for caja_id, grupo_caja in grupo_producto.groupby('caja_tipo_id'):
            caja = cajas[caja_id]
            asignacion = Asignacion(producto, caja)
            
            # Agregar todas las redimensiones válidas
            redimensiones_ordenadas = []
            for _, row in grupo_caja.iterrows():
                redimensiones_ordenadas.append({
                    'alto': row['alto'],
                    'ancho': row['ancho'],
                    'largo': row['largo'],
                    'utilizacion_pallet': row['utilizacion_pallet'],
                    'cantidad_cajas_pallet': row['cantidad_cajas_pallet']
                })
            
            # Ordenar por cajas_pallet y utilización (de mayor a menor)
            redimensiones_ordenadas = sorted(
                redimensiones_ordenadas,
                key=lambda x: (x['cantidad_cajas_pallet'], x['utilizacion_pallet']),
                reverse=True
            )            

            # Agregar redimensiones a la asignación
            for redim in redimensiones_ordenadas:
                asignacion.agregar_redimension_valida(redim)
            
            asignaciones_por_producto[codigo_producto][caja_id] = asignacion
                
    # Elegir grosor
    for caja_id, caja in cajas.items():
        caja.elegir_grosor(grosor_mm=grosor)
        
    return cajas, productos, asignaciones_por_producto

# %% [markdown]
# #### **Greedy 1: Elección por menor costo**

# %% [markdown]
# Empecemos eligiendo un grosor de 5mm para todos los tipos de cajas

# %%
def solucion_greedy(grosor, cajas, lista_productos_ordenados, asignaciones_por_producto, criterio):

    solucion = Solucion(grosor=grosor)
    cajas_redimensiones_fijadas = [] 

    for codigo_producto in lista_productos_ordenados:
        producto = productos[codigo_producto]
        asignaciones_producto = asignaciones_por_producto[codigo_producto]
        metricas = {}  # caja_id -> (volumen_total, costo_packaging, costo_flete, costo_total, utilizacion_pallet)
        
        for caja_id, asignacion in asignaciones_producto.items():
            caja = asignacion.caja
            # Volumen requerido actual (antes de asignar este producto)
            volumen_total = caja.unidades_total_requeridas()
            
            if caja_id not in cajas_redimensiones_fijadas:
                mejor_redimension = asignacion.redimensiones_validas[0]
            else:
                mejor_redimension = {'alto': cajas[caja_id].dim_interior_alto,
                                     'ancho': cajas[caja_id].dim_interior_ancho,
                                     'largo': cajas[caja_id].dim_interior_largo}
            
            alto_original = caja.dim_interior_alto
            ancho_original = caja.dim_interior_ancho
            largo_original = caja.dim_interior_largo
            caja.redimensionar(mejor_redimension['alto'], mejor_redimension['ancho'], mejor_redimension['largo'])
        
            # Tenemos que chequear nuevamente la asignacion porque si la caja ya fue redimensionada por otro
            # producto, quizás ésa no sea una redimension válida del producto actual
            if asignacion.es_asignacion_valida():
                # Costo simulado de asignar este producto a esta caja
                caja.asignar_producto(producto)
                utilizacion_pallet = caja.utilizacion_pallet()
                costo_packaging = asignacion.costo_packaging_producto_total()
                costo_flete = 150 * asignacion.cant_pallets_requeridas()
                costo_total = costo_packaging + costo_flete
                metricas[caja_id] = (volumen_total, costo_packaging, costo_flete, costo_total, utilizacion_pallet)
                
                # Revertimos la asignación para que no se aplique un descuento posterior
                caja.revocar_producto(producto)
            
            caja.redimensionar(alto_original, ancho_original, largo_original)
        
        if criterio == "minimizar_costo_total":
            caja_id_optima = min(metricas, key=lambda id: (metricas[id][3], -metricas[id][4], random.random()))
        elif criterio == "maximizar_volumen_tipo":        
            caja_id_optima = max(metricas, key=lambda id: (metricas[id][0], -metricas[id][3]))
        elif criterio == "minimizar_costo_flete":
            caja_id_optima = min(metricas, key=lambda id: (metricas[id][2]))
        elif criterio == "maximizar_utilizacion_pallet":
            caja_id_optima = max(metricas, key=lambda id: (metricas[id][4]))
                
        asignacion_optima = asignaciones_por_producto[codigo_producto][caja_id_optima]
        caja_optima = asignacion_optima.caja
            
        # Redimensionamos óptimamente el tipo de caja elegido
        if caja_id_optima not in cajas_redimensiones_fijadas:
            redimension = asignacion_optima.redimensiones_validas[0]
            caja_optima.redimensionar(redimension['alto'], redimension['ancho'], redimension['largo'])
            cajas_redimensiones_fijadas.append(caja_id_optima)
        
        solucion.agregar_asignacion(asignacion_optima)
    
    return solucion

# %% [markdown]
# Guardamos nuevamente cajas y productos, reiniciando toda asignación previa:

# %%
cajas, productos, asignaciones_por_producto = guardar_cajas_y_productos(grosor=5)

# %%
productos_conteo = []

for codigo_producto, asignaciones in asignaciones_por_producto.items():
    cantidad_cajas = len(asignaciones)  # Número de cajas asignables para este producto    
    productos_conteo.append({
        'codigo_producto': codigo_producto,
        'cantidad_cajas_asignables': cantidad_cajas
    })

# Ordenar de menor a mayor cantidad de cajas
productos_ordenados = sorted(
    productos_conteo,
    key=lambda x: x['cantidad_cajas_asignables'],
    reverse=False
)

lista_productos_ordenados = [item['codigo_producto'] for item in productos_ordenados]

# %%
solucion_greedy1 = solucion_greedy(5, cajas, lista_productos_ordenados, asignaciones_por_producto, criterio="minimizar_costo_total")
solucion_greedy1.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 55
# Costo packaging: 31787590.59
# Costo flete: 172178700
# Costo total: 203966290.59
# Utilización de pallet promedio: 0.9390915851331946
# Utilización de caja promedio: 0.9391019681652123

# %%
solucion_greedy1.resumen_por_asignacion()
# Out:
#     codigo_producto  demanda_total                           caja_id  \
# 0            BR0001        1546613  2060590a59a5c59ff1bb32dbffe1028b
# 1            BR0002         139211  6d3c3bcdfc4034e3424078243e7668a1
# 2            BR0003         172506  cb9988b0557e22e3abc2bbe0a56967d0
# 3            BR0004         271715  6bd5fa9e984e7243519003fc969aa30d
# 4            BR0005           7586  a053806f0b23db27a17e90bf971c8a62
# ..              ...            ...                               ...
# 422          BR0417           2761  ef2c4cbdd2be88c4d7a73fe0a429c842
# 423          BR0418           3942  ef2c4cbdd2be88c4d7a73fe0a429c842
# 424          BR0419          43300  161332db17a4c8bcba8a5651098cbe91
# 425          BR0420         205852  1c01c33ced1f5bfdb36a399ac98e0c68
# 426          BR0421         145803  ea6403e25e3a52198dad19251c207a47
#
#      utilizacion_pallet  utilizacion_caja  descuento_buenos_aires  \
# 0              0.886717          0.956439                     0.1
# 1              0.963776          0.962815                     0.1
# 2              0.971373          0.982264                    -0.2
# 3              0.964861          0.972285                    -0.2
# 4              0.921448          0.926740                     0.1
# ..                  ...               ...                     ...
# 422            0.896186          0.890532                     0.1
# 423            0.896186          0.890532                     0.1
# 424            0.983425          0.957743                    -0.1
# 425            0.922054          0.914336                    -0.2
# 426            0.925622          0.869837                    -0.2
#
#      descuento_curitiba  descuento_santiago  descuento_monterrey  \
# 0                  -0.3                -0.3                 -0.1
# 1                  -0.2                -0.3                  0.1
# 2                  -0.3                -0.2                  0.0
# 3                  -0.3                -0.3                 -0.1
# 4                  -0.2                 0.1                  0.1
# ..                  ...                 ...                  ...
# 422                -0.3                -0.3                 -0.2
# 423                -0.3                -0.3                 -0.2
# 424                -0.2                -0.2                 -0.2
# 425                -0.3                -0.2                 -0.3
# 426                -0.3                -0.3                 -0.3
#
#      descuento_bakersfield  costo_packaging  cant_pallets  costo_flete  \
# 0                     -0.2        770200.13         38667      5800050
# 1                     -0.2         77958.16          2901       435150
# 2                     -0.2         96603.36          2157       323550
# 3                     -0.3        133140.35          4853       727950
# 4                     -0.2          4248.16           159        23850
# ..                     ...              ...           ...          ...
# 422                    0.1          1352.89            50         7500
# 423                    0.1          1931.58            71        10650
# 424                   -0.3         24248.00           602        90300
# 425                    0.1        100867.48          3217       482550
# 426                   -0.3         71443.47          2604       390600
#
#      costo_total
# 0     6570250.13
# 1      513108.16
# 2      420153.36
# 3      861090.35
# 4       28098.16
# ..           ...
# 422      8852.89
# 423     12581.58
# 424    114548.00
# 425    583417.48
# 426    462043.47
#
# [427 rows x 14 columns]

# %%
solucion_greedy1.exportar_submmit(nombre_csv="2-greedy_5mm_redim_min_costo_total")

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
# Ordenamos los productos según la cantidad de cajas asignables de menor a mayor
productos_ordenados = sorted(productos, key=lambda p: len(p.cajas_asignables))

solucion_greedy2 = solucion_greedy(5, cajas, productos_ordenados, criterio="minimizar_costo_flete")

#solucion_greedy1.exportar_submmit(nombre_csv="2-greedy1_5mm")
solucion_greedy2.resumen_por_asignacion()
solucion_greedy2.resumen_general()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[224], line 1
# ----> 1 cajas, productos = guardar_cajas_y_productos(grosor=5)
#       2 # Ordenamos los productos según la cantidad de cajas asignables de menor a mayor
#       3 productos_ordenados = sorted(productos, key=lambda p: len(p.cajas_asignables))
#
# ValueError: too many values to unpack (expected 2)

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
# Ordenamos los productos según la cantidad de cajas asignables de menor a mayor
productos_ordenados = sorted(productos, key=lambda p: len(p.cajas_asignables))

solucion_greedy3 = solucion_greedy(5, cajas, productos_ordenados, criterio="maximizar_utilizacion_pallet")

#solucion_greedy1.exportar_submmit(nombre_csv="2-greedy1_5mm")
solucion_greedy3.resumen_por_asignacion()
solucion_greedy3.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 17
# Costo packaging: 31121207.040000003
# Costo flete: 155073300
# Costo total: 186194507.04
# Utilización de pallet promedio: 0.9529277809508822
# Utilización de caja promedio: 1.0302309985046123

# %%
solucion_greedy3.resumen_por_asignacion()
# Out:
#     codigo_producto  demanda_total  cant_cajas_asignables  \
# 0            BR0001        1546613                     72
# 1            BR0002         139211                     83
# 2            BR0003         172506                     43
# 3            BR0004         271715                     88
# 4            BR0005           7586                    106
# ..              ...            ...                    ...
# 422          BR0417           2761                     50
# 423          BR0418           3942                     50
# 424          BR0419          43300                     54
# 425          BR0420         205852                     41
# 426          BR0421         145803                     56
#
#                               caja_id  utilizacion_pallet  utilizacion_caja  \
# 0    2060590a59a5c59ff1bb32dbffe1028b            0.970288          1.052083
# 1    5229dfb764d843b66341f7ca5cdec3dd            0.983974          1.271230
# 2    67894c5a8355ca9b7e57b96362fa45f1            0.982876          0.970414
# 3    5229dfb764d843b66341f7ca5cdec3dd            0.983974          1.095214
# 4    5229dfb764d843b66341f7ca5cdec3dd            0.983974          1.167981
# ..                                ...                 ...               ...
# 422  ea6403e25e3a52198dad19251c207a47            0.844404          0.947362
# 423  ea6403e25e3a52198dad19251c207a47            0.844404          0.947362
# 424  161332db17a4c8bcba8a5651098cbe91            0.983425          0.957743
# 425  1e68edd4dd3edf793634e204ec225c3b            0.949000          0.887343
# 426  1e68edd4dd3edf793634e204ec225c3b            0.949000          0.974338
#
#      descuento_buenos_aires  descuento_curitiba  descuento_santiago  \
# 0                       0.1                -0.3                -0.3
# 1                      -0.3                -0.3                -0.3
# 2                      -0.2                -0.3                -0.2
# 3                      -0.3                -0.3                -0.3
# 4                      -0.3                -0.3                -0.3
# ..                      ...                 ...                 ...
# 422                    -0.3                -0.3                -0.3
# 423                    -0.3                -0.3                -0.3
# 424                    -0.3                -0.3                -0.2
# 425                    -0.2                -0.3                -0.3
# 426                    -0.2                -0.3                -0.3
#
#      descuento_monterrey  descuento_bakersfield  costo_packaging  \
# 0                   -0.1                   -0.2        770200.13
# 1                   -0.3                   -0.3         68213.39
# 2                    0.0                   -0.2         96603.36
# 3                   -0.3                   -0.3        133140.35
# 4                   -0.3                   -0.3          3717.14
# ..                   ...                    ...              ...
# 422                 -0.2                    0.1          1352.89
# 423                 -0.2                    0.1          1931.58
# 424                 -0.2                   -0.3         24248.00
# 425                 -0.3                   -0.3        100867.48
# 426                 -0.3                   -0.3         71443.47
#
#      cant_pallets  costo_flete  costo_total
# 0           32223      4833450   5603650.13
# 1            2176       326400    394613.39
# 2            2157       323550    420153.36
# 3            4246       636900    770040.35
# 4             119        17850     21567.14
# ..            ...          ...          ...
# 422            50         7500      8852.89
# 423            71        10650     12581.58
# 424           602        90300    114548.00
# 425          3217       482550    583417.48
# 426          2279       341850    413293.47
#
# [427 rows x 15 columns]

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
# Ordenamos los productos según la cantidad de cajas asignables de menor a mayor
productos_ordenados = sorted(productos, key=lambda p: len(p.cajas_asignables))

solucion_greedy4 = solucion_greedy(5, cajas, productos_ordenados, criterio="maximizar_volumen_tipo")

#solucion_greedy1.exportar_submmit(nombre_csv="2-greedy1_5mm")
solucion_greedy4.resumen_por_asignacion()
solucion_greedy4.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 8
# Costo packaging: 30729293.20999999
# Costo flete: 150772200
# Costo total: 181501493.20999998
# Utilización de pallet promedio: 0.8653388481885613
# Utilización de caja promedio: 1.1722415356961153

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
# Ordenamos los productos según la cantidad de cajas asignables de menor a mayor
productos_ordenados = sorted(productos, key=lambda p: p.demanda_total(), reverse=True)

solucion_greedy5 = solucion_greedy(5, cajas, productos_ordenados, criterio="minimizar_costo_total")

#solucion_greedy1.exportar_submmit(nombre_csv="2-greedy1_5mm")
solucion_greedy5.resumen_por_asignacion()
solucion_greedy5.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 24
# Costo packaging: 31271719.149999965
# Costo flete: 131910900
# Costo total: 163182619.14999998
# Utilización de pallet promedio: 0.9231614032864329
# Utilización de caja promedio: 1.2561854079987966

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
# Ordenamos los productos según la cantidad de cajas asignables de menor a mayor
productos_ordenados = sorted(productos, key=lambda p: p.demanda_total(), reverse=True)

solucion_greedy6 = solucion_greedy(5, cajas, productos_ordenados, criterio="minimizar_costo_flete")

#solucion_greedy1.exportar_submmit(nombre_csv="2-greedy1_5mm")
solucion_greedy6.resumen_por_asignacion()
solucion_greedy6.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 27
# Costo packaging: 31306458.399999984
# Costo flete: 131892150
# Costo total: 163198608.39999998
# Utilización de pallet promedio: 0.9234925447347335
# Utilización de caja promedio: 1.2558748412249596

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
# Ordenamos los productos según la cantidad de cajas asignables de menor a mayor
productos_ordenados = sorted(productos, key=lambda p: p.demanda_total(), reverse=True)

solucion_greedy7 = solucion_greedy(5, cajas, productos_ordenados, criterio="maximizar_utilizacion_pallet")

#solucion_greedy1.exportar_submmit(nombre_csv="2-greedy1_5mm")
solucion_greedy7.resumen_por_asignacion()
solucion_greedy7.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 17
# Costo packaging: 31121207.03999998
# Costo flete: 155073300
# Costo total: 186194507.04
# Utilización de pallet promedio: 0.9529277809508823
# Utilización de caja promedio: 1.0302309985046119

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
# Ordenamos los productos según la cantidad de cajas asignables de menor a mayor
productos_ordenados = sorted(productos, key=lambda p: p.demanda_total(), reverse=True)

solucion_greedy8 = solucion_greedy(5, cajas, productos_ordenados, criterio="maximizar_volumen_tipo")

#solucion_greedy1.exportar_submmit(nombre_csv="2-greedy1_5mm")
solucion_greedy8.resumen_por_asignacion()
solucion_greedy8.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 10
# Costo packaging: 30731432.619999956
# Costo flete: 144668850
# Costo total: 175400282.61999995
# Utilización de pallet promedio: 0.9023581694264049
# Utilización de caja promedio: 1.1736096055855718

# %% [markdown]
# #### **Greedy 2: Elección por mayor volumen**

# %% [markdown]
# Greedy (2)
#
# Ordenamos los productos de menor a mayor según la cantidad de tipos de cajas asignables.
# Iteramos los productos p desde el menor:
#     (HACER EN FACTIBILIDAD) Ver factibilidad de caja por resistencia a comprension + headspace
#     Asignar a p el tipo de caja con mayor volúmen actualmente
#
# Con los descuentos finales, vuelvo a calcular cada costo de producto

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
productos_ordenados = sorted(productos, key=lambda p: len(p.cajas_asignables))

# %%
solucion_greedy2 = Solucion(grosor=5)

for producto in productos_ordenados:
    metricas = {}  # caja_id -> (volumen_total, costo_total)
    
    for caja_id in producto.cajas_asignables:
        caja = buscar_caja_por_id(caja_id)
        
        # volumen requerido actual (antes de asignar este producto)
        volumen_total = caja.unidades_total_requeridas()
        
        # costo simulado de asignar este producto a esta caja
        asignacion = Asignacion(producto, caja)
        caja.asignar_producto(producto)
        costo_packaging = asignacion.costo_packaging_producto_total()
        costo_flete = 150 * asignacion.cant_pallets_requeridas()
        costo_total = costo_packaging + costo_flete
        caja.revocar_producto(producto)
        
        metricas[caja_id] = (volumen_total, costo_total)
    
    # criterio: mayor volumen_total primero, y en caso de empate, menor costo_total
    caja_id_optima = max(metricas, key=lambda id: (metricas[id][0], -metricas[id][1]))
    caja_optima = buscar_caja_por_id(caja_id_optima)
    
    asignacion = Asignacion(producto, caja_optima)
    solucion_greedy2.agregar_asignacion(asignacion)

solucion_greedy2.exportar_submmit(nombre_csv="3-greedy2_5mm")
solucion_greedy2.resumen_por_asignacion()
# Out:
#     codigo_producto  demanda_total  cant_cajas_asignables  \
# 0            BR0001        1546613                     72
# 1            BR0002         139211                     83
# 2            BR0003         172506                     43
# 3            BR0004         271715                     88
# 4            BR0005           7586                    106
# ..              ...            ...                    ...
# 422          BR0417           2761                     50
# 423          BR0418           3942                     50
# 424          BR0419          43300                     54
# 425          BR0420         205852                     41
# 426          BR0421         145803                     56
#
#                               caja_id  utilizacion_pallet  utilizacion_caja  \
# 0    2060590a59a5c59ff1bb32dbffe1028b            0.970288          1.052083
# 1    63849e2a342c002e41cdca735b7ffa35            0.887333          1.231162
# 2    8f6cdeebd6a09f639e27ef1cbb567311            0.769843          1.252844
# 3    63849e2a342c002e41cdca735b7ffa35            0.887333          1.060694
# 4    63849e2a342c002e41cdca735b7ffa35            0.887333          1.131168
# ..                                ...                 ...               ...
# 422  082c1cdb42b1abd201403ca33ca11ef0            0.840725          1.238095
# 423  082c1cdb42b1abd201403ca33ca11ef0            0.840725          1.238095
# 424  082c1cdb42b1abd201403ca33ca11ef0            0.840725          1.126737
# 425  082c1cdb42b1abd201403ca33ca11ef0            0.840725          1.138808
# 426  082c1cdb42b1abd201403ca33ca11ef0            0.840725          1.250456
#
#      descuento_buenos_aires  descuento_curitiba  descuento_santiago  \
# 0                      -0.3                -0.3                -0.3
# 1                      -0.3                -0.3                -0.3
# 2                      -0.3                -0.3                -0.3
# 3                      -0.3                -0.3                -0.3
# 4                      -0.3                -0.3                -0.3
# ..                      ...                 ...                 ...
# 422                    -0.3                -0.3                -0.3
# 423                    -0.3                -0.3                -0.3
# 424                    -0.3                -0.3                -0.3
# 425                    -0.3                -0.3                -0.3
# 426                    -0.3                -0.3                -0.3
#
#      descuento_monterrey  descuento_bakersfield  costo_packaging  \
# 0                   -0.1                   -0.3        770200.13
# 1                   -0.3                   -0.3         68213.39
# 2                   -0.2                   -0.3         84527.94
# 3                   -0.3                   -0.3        133140.35
# 4                   -0.3                   -0.3          3717.14
# ..                   ...                    ...              ...
# 422                 -0.3                   -0.3          1352.89
# 423                 -0.3                   -0.3          1931.58
# 424                 -0.3                   -0.3         21217.00
# 425                 -0.3                   -0.3        100867.48
# 426                 -0.3                   -0.3         71443.47
#
#      cant_pallets  costo_flete  costo_total
# 0           32223      4833450   5603650.13
# 1            2486       372900    441113.39
# 2            2157       323550    408077.94
# 3            4853       727950    861090.35
# 4             136        20400     24117.14
# ..            ...          ...          ...
# 422            39         5850      7202.89
# 423            55         8250     10181.58
# 424           602        90300    111517.00
# 425          2860       429000    529867.48
# 426          2026       303900    375343.47
#
# [427 rows x 15 columns]

# %%
solucion_greedy2.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 8
# Costo packaging: 30729293.20999999
# Costo flete: 150772200
# Costo total: 181501493.20999998
# Utilización de pallet promedio: 0.8653388481885613
# Utilización de caja promedio: 1.1722415356961153

# %% [markdown]
# #### **Greedy 3: Ordenamiento de productos según su demanda total**

# %% [markdown]
# Greedy (3)
#
# Rehacer Greedy 1 y 2 ordenando los productos de mayor a menor según la demanda.

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)

# Ordenamos ahora los productos según la demanda total de mayor a menor
productos_ordenados = sorted(productos, key=lambda p: p.demanda_total(), reverse=True)

# %%
solucion_greedy3 = Solucion(grosor=5)

for producto in productos_ordenados:
    costos_totales = {}
    for caja_id in producto.cajas_asignables:
        caja = buscar_caja_por_id(caja_id)
        asignacion = Asignacion(producto, caja)
        caja.asignar_producto(producto)
        costo_packaging = asignacion.costo_packaging_producto_total()
        costo_flete = 150 * asignacion.cant_pallets_requeridas()
        
        costo_total = costo_packaging + costo_flete
        costos_totales[caja_id] = costo_total
        
        caja.revocar_producto(producto)
    
    caja_id_optima = min(costos_totales, key=costos_totales.get)
    caja_optima = buscar_caja_por_id(caja_id_optima)
    
    asignacion = Asignacion(producto, caja_optima)
    solucion_greedy3.agregar_asignacion(asignacion)
    
solucion_greedy3.exportar_submmit(nombre_csv="4-greedy3_5mm")
solucion_greedy3.resumen_por_asignacion()
# Out:
#     codigo_producto  demanda_total  cant_cajas_asignables  \
# 0            BR0001        1546613                     72
# 1            BR0002         139211                     83
# 2            BR0003         172506                     43
# 3            BR0004         271715                     88
# 4            BR0005           7586                    106
# ..              ...            ...                    ...
# 422          BR0417           2761                     50
# 423          BR0418           3942                     50
# 424          BR0419          43300                     54
# 425          BR0420         205852                     41
# 426          BR0421         145803                     56
#
#                               caja_id  utilizacion_pallet  utilizacion_caja  \
# 0    414d4cf5c1bc8a346f7e4445ede7acbd            0.907881          1.323144
# 1    5229dfb764d843b66341f7ca5cdec3dd            0.983974          1.271230
# 2    eb8c91d6266d086a541d9c7411a9d92f            0.960363          1.100671
# 3    228ba4e5ea3c7574cbd9ce77434d4525            0.925275          1.321090
# 4    161332db17a4c8bcba8a5651098cbe91            0.983425          1.322476
# ..                                ...                 ...               ...
# 422  082c1cdb42b1abd201403ca33ca11ef0            0.840725          1.238095
# 423  082c1cdb42b1abd201403ca33ca11ef0            0.840725          1.238095
# 424  1aef9680c5b131e489d3ac61e5ace43f            0.938391          1.244446
# 425  519a80871f454928779db9ed3e039e2b            0.933183          1.142388
# 426  519a80871f454928779db9ed3e039e2b            0.933183          1.254387
#
#      descuento_buenos_aires  descuento_curitiba  descuento_santiago  \
# 0                       0.1                -0.3                -0.2
# 1                      -0.2                -0.3                -0.3
# 2                      -0.1                -0.2                -0.3
# 3                      -0.2                -0.3                -0.3
# 4                      -0.2                -0.2                -0.3
# ..                      ...                 ...                 ...
# 422                    -0.3                -0.3                -0.3
# 423                    -0.3                -0.3                -0.3
# 424                    -0.3                -0.3                -0.2
# 425                    -0.2                -0.3                -0.3
# 426                    -0.2                -0.3                -0.3
#
#      descuento_monterrey  descuento_bakersfield  costo_packaging  \
# 0                   -0.1                    0.1        772060.94
# 1                    0.1                   -0.2         68213.39
# 2                    0.1                   -0.3         84527.94
# 3                   -0.3                   -0.3        133140.35
# 4                    0.1                   -0.2          4248.16
# ..                   ...                    ...              ...
# 422                 -0.2                   -0.2          1352.89
# 423                 -0.2                   -0.2          1931.58
# 424                 -0.2                    0.0         24248.00
# 425                 -0.3                   -0.3        100867.48
# 426                 -0.3                   -0.3         71443.47
#
#      cant_pallets  costo_flete  costo_total
# 0           27619      4142850   4914910.94
# 1            2176       326400    394613.39
# 2            1961       294150    378677.94
# 3            3774       566100    699240.35
# 4             106        15900     20148.16
# ..            ...          ...          ...
# 422            39         5850      7202.89
# 423            55         8250     10181.58
# 424           493        73950     98198.00
# 425          2574       386100    486967.48
# 426          1823       273450    344893.47
#
# [427 rows x 15 columns]

# %%
solucion_greedy3.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 24
# Costo packaging: 31271719.149999965
# Costo flete: 131910900
# Costo total: 163182619.14999998
# Utilización de pallet promedio: 0.9231614032864329
# Utilización de caja promedio: 1.2561854079987966

# %%
cajas, productos = guardar_cajas_y_productos(grosor=5)
productos_ordenados = sorted(productos, key=lambda p: p.demanda_total(), reverse=True)

# %%
solucion_greedy4 = Solucion(grosor=5)

for producto in productos_ordenados:
    metricas = {}  # caja_id -> (volumen_total, costo_total)
    
    for caja_id in producto.cajas_asignables:
        caja = buscar_caja_por_id(caja_id)
        
        # volumen requerido actual (antes de asignar este producto)
        volumen_total = caja.unidades_total_requeridas()
        
        # costo simulado de asignar este producto a esta caja
        asignacion = Asignacion(producto, caja)
        caja.asignar_producto(producto)
        costo_packaging = asignacion.costo_packaging_producto_total()
        costo_flete = 150 * asignacion.cant_pallets_requeridas()
        costo_total = costo_packaging + costo_flete
        caja.revocar_producto(producto)
        
        metricas[caja_id] = (volumen_total, costo_total)
    
    # criterio: mayor volumen_total primero, y en caso de empate, menor costo_total
    caja_id_optima = max(metricas, key=lambda id: (metricas[id][0], -metricas[id][1]))
    caja_optima = buscar_caja_por_id(caja_id_optima)
    
    asignacion = Asignacion(producto, caja_optima)
    solucion_greedy4.agregar_asignacion(asignacion)

solucion_greedy4.exportar_submmit(nombre_csv="5-greedy4_5mm")
solucion_greedy4.resumen_por_asignacion()
# Out:
#     codigo_producto  demanda_total  cant_cajas_asignables  \
# 0            BR0001        1546613                     72
# 1            BR0002         139211                     83
# 2            BR0003         172506                     43
# 3            BR0004         271715                     88
# 4            BR0005           7586                    106
# ..              ...            ...                    ...
# 422          BR0417           2761                     50
# 423          BR0418           3942                     50
# 424          BR0419          43300                     54
# 425          BR0420         205852                     41
# 426          BR0421         145803                     56
#
#                               caja_id  utilizacion_pallet  utilizacion_caja  \
# 0    5914abeae491eab8612131985b15994f            0.945868          1.267782
# 1    5914abeae491eab8612131985b15994f            0.945868          1.152155
# 2    519a80871f454928779db9ed3e039e2b            0.933183          1.024045
# 3    5914abeae491eab8612131985b15994f            0.945868          0.992626
# 4    5914abeae491eab8612131985b15994f            0.945868          1.058577
# ..                                ...                 ...               ...
# 422  1a3ffa8018de4637afcdd1e390e2602a            0.784865          1.175879
# 423  1a3ffa8018de4637afcdd1e390e2602a            0.784865          1.175879
# 424  519a80871f454928779db9ed3e039e2b            0.933183          1.130279
# 425  519a80871f454928779db9ed3e039e2b            0.933183          1.142388
# 426  519a80871f454928779db9ed3e039e2b            0.933183          1.254387
#
#      descuento_buenos_aires  descuento_curitiba  descuento_santiago  \
# 0                      -0.3                -0.3                -0.3
# 1                      -0.3                -0.3                -0.3
# 2                      -0.3                -0.3                -0.3
# 3                      -0.3                -0.3                -0.3
# 4                      -0.3                -0.3                -0.3
# ..                      ...                 ...                 ...
# 422                    -0.3                -0.3                -0.3
# 423                    -0.3                -0.3                -0.3
# 424                    -0.3                -0.3                -0.3
# 425                    -0.3                -0.3                -0.3
# 426                    -0.3                -0.3                -0.3
#
#      descuento_monterrey  descuento_bakersfield  costo_packaging  \
# 0                   -0.3                   -0.3        757840.37
# 1                   -0.3                   -0.3         68213.39
# 2                   -0.3                   -0.3         84527.94
# 3                   -0.3                   -0.3        133140.35
# 4                   -0.3                   -0.3          3717.14
# ..                   ...                    ...              ...
# 422                 -0.3                   -0.3          1352.89
# 423                 -0.3                   -0.3          1931.58
# 424                 -0.3                   -0.3         21217.00
# 425                 -0.3                   -0.3        100867.48
# 426                 -0.3                   -0.3         71443.47
#
#      cant_pallets  costo_flete  costo_total
# 0           27619      4142850   4900690.37
# 1            2486       372900    441113.39
# 2            2157       323550    408077.94
# 3            4853       727950    861090.35
# 4             136        20400     24117.14
# ..            ...          ...          ...
# 422            44         6600      7952.89
# 423            62         9300     11231.58
# 424           542        81300    102517.00
# 425          2574       386100    486967.48
# 426          1823       273450    344893.47
#
# [427 rows x 15 columns]

# %%
solucion_greedy4.resumen_general()
# Out:
# Situación original
# --------------------------------------------------
# Número de tipos de cajas distintos: 204
# Costo packaging: 30295472.424999997
# Costo flete: 179068800
# Costo total: 209364272.425
# Utilización de pallet promedio: 0.8320794116391749
# Utilización de caja promedio: 1.0
#
# Situación nueva
# --------------------------------------------------
# Grosor elegido: 5mm
# Número de tipos de cajas distintos: 10
# Costo packaging: 30731432.619999956
# Costo flete: 144668850
# Costo total: 175400282.61999995
# Utilización de pallet promedio: 0.9023581694264049
# Utilización de caja promedio: 1.1736096055855718

# %% [markdown]
# Partiendo de la solucion, veo si la puedo mejorar
#
# En cada paso:
#     Cambio el tipo de caja, y me fijo si con los descuentos puedo tener un menor costo
